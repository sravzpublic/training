# %%
# %reload_ext autoreload
# %autoreload 2

import datetime
import numpy as np
import matplotlib.pyplot as plt

from src import util, asset
from src import tears

ae = asset.engine()
price_df = ae.get_historical_price('fut_gold')[['Settle']]

# %%
tears.get_rolling_stats(price_df, sravzid = 'fut_gold', return_fig=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-aea55b87a197> in <module>()
# ----> 1 tears.get_rolling_stats(price_df, return_fig=True)
#
# ~/workspace/training/notebooks/src/tears.py in get_rolling_stats(price_df, return_fig)
#     273     price_df[col].plot(label=col, ax=ax_price_plot)
#     274     ax_price_plot.set_title(
# --> 275         '{0} {1} Price'.format(sravzid, col))
#     276     ax_price_plot.legend()
#     277
#
# NameError: name 'sravzid' is not defined
