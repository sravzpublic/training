# %%
# %reload_ext autoreload
# %autoreload 2

import datetime
import numpy as np
import matplotlib.pyplot as plt

from src import util, asset, portfolio
ae = asset.engine()
pe = portfolio.engine()

# %%
pe.get_scatter_plot_daily_return(['fut_gold', 'idx_us_spx'])
