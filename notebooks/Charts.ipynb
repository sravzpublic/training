# %%
# %reload_ext autoreload
# %autoreload 2

import datetime
import numpy as np
import matplotlib.pyplot as plt

from src import util, asset
ae = asset.engine()

# %%
display(ae.get_assets(['fut_gold', 'fut_oil']).head())
display(ae.get_assets(['fut_gold', 'fut_oil']).tail())
# Out:
#                            Volumefut_gold  Highfut_gold  Lastfut_gold  \
# Date
# 2019-07-26 00:00:00+00:00          298770        1424.8        1418.7
# 2019-07-25 00:00:00+00:00          475099        1434.1        1414.1
# 2019-07-24 00:00:00+00:00          312640        1430.0        1425.7
# 2019-07-23 00:00:00+00:00          381571        1431.4        1418.0
# 2019-07-22 00:00:00+00:00          248096        1430.8        1425.2
#
#                            Lowfut_gold  OpenInterestfut_gold  Openfut_gold  \
# Date
# 2019-07-26 00:00:00+00:00       1412.9                130931        1414.9
# 2019-07-25 00:00:00+00:00       1411.1                196135        1426.8
# 2019-07-24 00:00:00+00:00       1416.7                236233        1418.6
# 2019-07-23 00:00:00+00:00       1414.6                276220        1426.0
# 2019-07-22 00:00:00+00:00       1423.0                290181        1428.5
#
#                            Changefut_gold  Settlefut_gold
# Date
# ...

# %%
ae.get_combined_charts(['fut_gold', 'fut_oil'])
