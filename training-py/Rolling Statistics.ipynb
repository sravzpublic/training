# %%
# %reload_ext autoreload
# %autoreload 2


import sys
sys.path.append("./")
sys.path.append("./src/")

from src import asset
from src import tears

ae = asset.engine()
price_df = ae.get_historical_price('fut_us_gc')[['AdjustedClose']]
print("Price DataFrame Head:", price_df.head())
print("Price DataFrame Tail:", price_df.tail())
# Out:
# /home/ubuntu/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pyfolio/pos.py:27: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   'Module "zipline.assets" not found; multipliers will not be applied'
# Price DataFrame Head:             AdjustedClose
# Date
# 1984-11-05          347.6
# 1984-11-06          345.2
# 1984-11-07          350.5
# 1984-11-08          347.9
# 1984-11-09          345.8
# Price DataFrame Tail:             AdjustedClose
# Date
# 2023-07-10         1931.0
# 2023-07-11         1937.1
# 2023-07-12         1961.7
# 2023-07-13         1963.8
# 2023-07-14         1964.4

# %%
tears.get_rolling_stats(price_df, sravzid = 'fut_us_gc', return_fig=True)
