# %%
'''
    © Sravz Ltd
    Run PCA@Sravz: https://sravz.com/analytics/all?analyticsType=PCA%20Analysis&assetType=portfolio 
    Docs@Sravz: https://docs.sravz.com/docs/analytics/pca-analysis/
'''
import numpy as np
import matplotlib.pyplot as plt
import sys
import os
sys.path.append(f"{os.getcwd()}/src")
from src import asset, portfolio
ae = asset.engine()
pe = portfolio.engine()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_420/1927493344.py in <module>
#       8 import sys
#       9 import pathlib
# ---> 10 sys.path.append(f"{pathlib.Path(__file__).parent.resolve()}/src")
#      11 from src import asset, portfolio
#      12 ae = asset.engine()
#
# NameError: name '__file__' is not defined

# %%
pe.get_scatter_plot_daily_return(['fut_gold', 'idx_us_spx'])
