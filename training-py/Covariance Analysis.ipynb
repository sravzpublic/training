# %%
# %reload_ext autoreload
# %autoreload 2

import sys
sys.path.append("./")
sys.path.append("./src/")

import datetime
import numpy as np
import matplotlib.pyplot as plt

from src import util, asset, portfolio
ae = asset.engine()
pe = portfolio.engine()

# %%
fut_gold_price_df = ae.get_historical_price('fut_us_gc')
display(fut_gold_price_df.tail(2))
display(fut_gold_price_df.head(2))
# Out:
#             Volume   Open   High    Low  Close  AdjustedClose
# Date
# 1984-11-05   35780  347.6  347.6  347.6  347.6          347.6
# 1984-11-06   26740  345.2  346.0  345.2  345.2          345.2

# %%
fut_gold_price_df['AdjustedClose'].plot(kind='line')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
portfolio_assets_percent_daily_returns_df = pe.get_percent_daily_returns(['fut_us_gc', 'idx_us_gspc'])

# %%
prortfolio_percent_daily_returns_df = pe.get_portfolio_daily_returns(portfolio_assets_percent_daily_returns_df)

# %%
pe.create_portfolio_correlation_report(portfolio_assets_percent_daily_returns_df, 
                                               prortfolio_percent_daily_returns_df)
