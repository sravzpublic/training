# %%
# %reload_ext autoreload
# %autoreload 2

import datetime
import numpy as np
import matplotlib.pyplot as plt

from src import util, asset
ae = asset.engine()

# %%
display(ae.get_assets(['fut_gold', 'idx_us_spx']).head())
display(ae.get_assets(['fut_gold', 'idx_us_spx']).tail())
# Out:
#                            Volumefut_gold  Highfut_gold  Lastfut_gold  \
# Date
# 2019-10-03 00:00:00+00:00          1213.0        1518.2        1506.1
# 2019-10-02 00:00:00+00:00           205.0        1503.7        1498.9
# 2019-10-01 00:00:00+00:00           219.0        1485.5        1479.0
# 2019-09-30 00:00:00+00:00          1078.0        1495.9        1472.1
# 2019-09-27 00:00:00+00:00          7827.0        1506.1        1495.9
#
#                            Lowfut_gold  OpenInterestfut_gold  Openfut_gold  \
# Date
# 2019-10-03 00:00:00+00:00       1496.6                   0.0        1497.4
# 2019-10-02 00:00:00+00:00       1474.1                   0.0        1476.6
# 2019-10-01 00:00:00+00:00       1458.3                   0.0        1468.7
# 2019-09-30 00:00:00+00:00       1463.5                   0.0        1495.9
# 2019-09-27 00:00:00+00:00       1485.6                   0.0        1504.2
#
#                            Changefut_gold  Settlefut_gold  Volumeidx_us_spx  \
# ...

# %%
ae.get_combined_charts(['fut_gold', 'idx_us_spx'])
