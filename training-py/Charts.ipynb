# %%
# %reload_ext autoreload
# %autoreload 2

import sys
sys.path.append("./")
sys.path.append("./src/")

import datetime
import numpy as np
import matplotlib.pyplot as plt

from src import util, asset
ae = asset.engine()

# %%
display(ae.get_assets(['fut_us_gc', 'idx_us_gspc']).head())
display(ae.get_assets(['fut_us_gc', 'idx_us_gspc']).tail())
# Out:
#             Volumefut_us_gc  Openfut_us_gc  Highfut_us_gc  Lowfut_us_gc  \
# 2023-07-14              0.0         1965.2         1967.8        1954.7
# 2023-07-13         241215.0         1962.7         1968.5        1956.6
# 2023-07-12         270869.0         1938.0         1965.1        1937.5
# 2023-07-11         189372.0         1930.8         1944.5        1929.8
# 2023-07-10         208085.0         1930.7         1933.7        1918.0
#
#             Closefut_us_gc  AdjustedClosefut_us_gc  Volumeidx_us_gspc  \
# 2023-07-14          1964.4                  1964.4       2.371250e+09
# 2023-07-13          1963.8                  1963.8       3.839530e+09
# 2023-07-12          1961.7                  1961.7       3.920290e+09
# 2023-07-11          1937.1                  1937.1       3.624220e+09
# 2023-07-10          1931.0                  1931.0       3.429600e+09
#
#             Openidx_us_gspc  Highidx_us_gspc  Lowidx_us_gspc  \
# ...

# %%
ae.get_combined_charts(['fut_us_gc', 'idx_us_gspc'])
