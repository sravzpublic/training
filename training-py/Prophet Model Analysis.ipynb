# %%
# %reload_ext autoreload
# %autoreload 2

import datetime
import numpy as np
import matplotlib.pyplot as plt

from src import util, asset, portfolio
from src import stocker

ae = asset.engine()
price_df = ae.get_historical_price('fut_gold')[['Last']]
price_df.head()
price_df.dtypes
# Out:
# Last    float64
# dtype: object

# %%
stocker.create_stocker_tear_sheet('fut_gold', stocker.CHART_TYPE_CREATE_PROPHET_MODEL, returns_df = price_df, number_of_years_back = 10)
# Out:
# /home/ubuntu/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# fut_gold Stocker Initialized. Data covers 2011-07-27 00:00:00 to 2019-10-03 00:00:00.
# Initial log joint probability = -12.3248
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1175.17   2.10578e-05       70.3642      0.3754      0.3754      131
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       1175.29   1.14609e-05       68.1217      0.7088      0.7088      261
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      278        1175.3   4.21508e-08       54.4445      0.4961      0.4961      367
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Predicted Price on 2020-01-01 00:00:00 = $1527.36

# %%
stocker.create_stocker_tear_sheet('fut_gold', stocker.CHART_TYPE_EVALUATE_PREDICTION, returns_df = price_df, number_of_years_back = 10)
# Out:
# /home/ubuntu/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# fut_gold Stocker Initialized. Data covers 2011-07-27 00:00:00 to 2019-10-03 00:00:00.
# Initial log joint probability = -9.01146
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1235.08   0.000278155       77.8861      0.4773      0.4773      129
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      106       1235.28    0.00142755       80.2155   1.695e-05       0.001      172  LS failed, Hessian reset
#      195       1235.68   0.000662361       79.2145   8.779e-06       0.001      339  LS failed, Hessian reset
#      199       1235.74    0.00202039       72.4117       0.342           1      344
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      249       1235.92   0.000213539       96.9212   2.673e-06       0.001      466  LS failed, Hessian reset
#      285       1235.94   2.71788e-06        63.805    3.85e-08       0.001      546  LS failed, Hessian reset
#      296       1235.94   1.41981e-08       66.9187      0.1146      0.3416      564
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#
# Prediction Range: 2018-10-03 00:00:00 to 2019-10-03 00:00:00.
#
# Predicted price on 2019-10-02 00:00:00 = $1066.87.
# Actual price on    2019-10-02 00:00:00 = $1498.90.
#
# Average Absolute Error on Training Data = $72.47.
# Average Absolute Error on Testing  Data = $276.73.
#
# When the model predicted an increase, the price increased 55.80% of the time.
# When the model predicted a  decrease, the price decreased  47.66% of the time.
#
# The actual value was within the 80% confidence interval 41.87% of the time.

# %%
stocker.create_stocker_tear_sheet('fut_gold', stocker.CHART_TYPE_CHANGE_POINT_PRIOR_ANALYSIS, returns_df = price_df, number_of_years_back = 10)
# Out:
# /home/ubuntu/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# fut_gold Stocker Initialized. Data covers 2011-07-27 00:00:00 to 2019-10-03 00:00:00.
# Initial log joint probability = -12.3248
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1143.19   3.75038e-08       5030.27      0.3988      0.3988      124
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      112       1143.19   2.16734e-09       5001.89     0.07149     0.07149      139
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -12.3248
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1175.17   2.10578e-05       70.3642      0.3754      0.3754      131
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       1175.29   1.14609e-05       68.1217      0.7088      0.7088      261
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      278        1175.3   4.21508e-08       54.4445      0.4961      0.4961      367
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -12.3248
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       85       1184.03   0.000931298       64.3177   1.886e-05       0.001      144  LS failed, Hessian reset
#       99       1184.13   0.000103821       27.2987       2.497      0.2497      164
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      175       1184.18    1.6723e-05       34.1321   4.982e-07       0.001      297  LS failed, Hessian reset
#      199       1184.19   4.64398e-06       37.7497           1           1      329
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      219       1184.19   3.12437e-07       29.8228      0.8503      0.8503      353
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -12.3248
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1190.49   0.000952155       17.4616      0.7674      0.7674      122
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      112       1190.57    0.00117748       40.7269   6.527e-05       0.001      170  LS failed, Hessian reset
#      144       1190.61    0.00024588       16.3335   1.461e-05       0.001      252  LS failed, Hessian reset
#      199       1190.68     0.0344799       22.1386           1           1      323
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      225       1191.01   0.000522893       43.0684   1.438e-05       0.001      390  LS failed, Hessian reset
#      249       1191.09   0.000242896       23.7479   1.699e-05       0.001      461  LS failed, Hessian reset
#      278       1191.11   0.000243615       18.2318   1.729e-05       0.001      551  LS failed, Hessian reset
#      299       1191.11   2.78106e-05       20.0462       0.355           1      579
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      352       1191.14   0.000190614       19.2566   1.059e-05       0.001      725  LS failed, Hessian reset
#      399       1191.16   4.60602e-06       17.5068      0.2916           1      795
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      466       1191.16   3.14886e-07       11.7503           1           1      887
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance

# %%
stocker.create_stocker_tear_sheet('fut_gold', stocker.CHART_TYPE_CHANGE_POINT_PRIOR_VALIDATION, returns_df = price_df, number_of_years_back = 10)
# Out:
# /home/ubuntu/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# fut_gold Stocker Initialized. Data covers 2011-07-27 00:00:00 to 2019-10-03 00:00:00.
#
# Validation Range 2017-10-03 00:00:00 to 2018-10-03 00:00:00.
#
# Initial log joint probability = -3.81933
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1718.05   2.83825e-07       5311.07           1           1      127
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      115       1718.06   5.19561e-07       5091.51   1.074e-10       0.001      198  LS failed, Hessian reset
#      127       1718.06   7.66992e-09       4734.35      0.4985      0.4985      211
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -3.81933
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1828.48     0.0215313       443.943           1           1      128
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       1830.85   2.19094e-05       63.2046           1           1      262
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      240       1831.95    0.00114044       142.645   1.213e-05       0.001      346  LS failed, Hessian reset
#      299       1832.95   6.77704e-05       52.2412      0.8566      0.8566      415
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      376       1833.36   0.000213808       87.1601   1.325e-06       0.001      565  LS failed, Hessian reset
#      399       1833.52   3.23739e-05       57.6881      0.6529      0.6529      592
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      459       1833.62   7.25649e-05       66.9231   1.312e-06       0.001      707  LS failed, Hessian reset
#      499       1833.62   3.18674e-06       51.0215           1           1      768
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      502       1833.62   2.96677e-06       67.6933   4.017e-08       0.001      806  LS failed, Hessian reset
#      520       1833.62   5.31823e-09       64.8091     0.01555     0.09936      834
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -3.81933
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1853.75    0.00230941       41.3663           1           1      123
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       1856.95   0.000457932       60.3109      0.3312      0.9617      252
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       1858.62     0.0506943       109.135       0.606           1      374
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      381       1859.15    0.00129242       61.5228   2.412e-05       0.001      508  LS failed, Hessian reset
#      399       1859.18   8.48784e-06       31.4443           1           1      532
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       1859.26    0.00126804       57.7688           1           1      659
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      586       1859.51   0.000776495       55.4299   1.911e-05       0.001      842  LS failed, Hessian reset
#      599       1859.56   1.24464e-05       41.5988      0.1371      0.1371      859
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      656       1859.58   3.55286e-07       34.2326      0.1575      0.4731      947
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -3.81933
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1871.24     0.0306636       324.597           1           1      120
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       1874.68    0.00484646       23.6068           1           1      238
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299        1875.8    0.00163372       37.5263           1           1      364
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       1876.37   0.000856113       33.7711           1           1      492
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       1876.98    0.00401946       18.5994           1           1      608
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      554       1876.99   3.08324e-07       11.7362      0.7376      0.7376      684
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#      cps  train_err  train_range  test_err  test_range
# 0  0.001     50.733      222.629   118.494     222.166
# 1  0.050     30.155      176.668   128.529     206.366
# 2  0.100     27.757      173.033   122.143     231.663
# 3  0.200     26.814      171.127   118.261     257.438

# %%
stocker.create_stocker_tear_sheet('fut_gold', stocker.CHART_TYPE_EVALUATE_PREDICTION_WITH_CHANGE_POINT, returns_df = price_df, number_of_years_back = 10)
# Out:
# /home/ubuntu/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# fut_gold Stocker Initialized. Data covers 2011-07-27 00:00:00 to 2019-10-03 00:00:00.
# Initial log joint probability = -9.01146
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1258.09    0.00404638       37.2296           1           1      124
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      127       1258.83   0.000200068       17.3244   7.576e-06       0.001      190  LS failed, Hessian reset
#      199       1259.25   0.000831773       13.4598      0.6529      0.6529      279
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      220        1259.3   0.000138835       6.09134    2.17e-05       0.001      343  LS failed, Hessian reset
#      269       1259.39   8.40149e-05       8.09384   8.093e-06       0.001      475  LS failed, Hessian reset
#      299       1259.45   0.000126271       8.00593           1           1      518
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      328       1259.47   0.000262144       18.1122   2.899e-05       0.001      589  LS failed, Hessian reset
#      399       1259.49   0.000529612       6.77142      0.4239           1      673
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      419       1259.52    0.00104972       24.3788   0.0001332       0.001      736  LS failed, Hessian reset
#      499       1259.57    0.00337306       11.0495           1           1      834
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      511       1259.58   9.24816e-05       8.95258   9.439e-06       0.001      916  LS failed, Hessian reset
#      599       1259.61    0.00012104       7.99686           1           1     1026
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      675       1259.66   0.000124503       12.1385   7.135e-06       0.001     1177  LS failed, Hessian reset
#      699       1259.69   0.000423212       9.05276      0.3478           1     1209
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       1259.71   1.65047e-05       6.87495           1           1     1341
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      855       1259.71   9.91426e-06       6.77522       2.328      0.2328     1414
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#
# Prediction Range: 2018-10-03 00:00:00 to 2019-10-03 00:00:00.
#
# Predicted price on 2019-10-02 00:00:00 = $938.97.
# Actual price on    2019-10-02 00:00:00 = $1498.90.
#
# Average Absolute Error on Training Data = $65.19.
# Average Absolute Error on Testing  Data = $360.78.
#
# When the model predicted an increase, the price increased 56.03% of the time.
# When the model predicted a  decrease, the price decreased  48.08% of the time.
#
# The actual value was within the 80% confidence interval 15.85% of the time.

# %%
stocker.create_stocker_tear_sheet('fut_gold', stocker.CHART_TYPE_PREDICT_FUTURE, returns_df = price_df, number_of_years_back = 10)
# Out:
# /home/ubuntu/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# fut_gold Stocker Initialized. Data covers 2011-07-27 00:00:00 to 2019-10-03 00:00:00.
# Initial log joint probability = -12.3248
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       1175.17   2.10578e-05       70.3642      0.3754      0.3754      131
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       1175.29   1.14609e-05       68.1217      0.7088      0.7088      261
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      278        1175.3   4.21508e-08       54.4445      0.4961      0.4961      367
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
#
# Predicted Increase:
#
#          Date     estimate     change        upper        lower
# 3  2019-10-06  1486.208112  14.207568  1724.717386  1224.736889
# 4  2019-10-07  1492.835203   6.627091  1744.262070  1237.647856
# 11 2019-10-14  1410.688731  10.308263  1669.347544  1165.209336
# 12 2019-10-15  1421.847307  11.158576  1662.944359  1165.595981
# 13 2019-10-16  1427.190457   5.343150  1668.420841  1165.427835
# 19 2019-10-22  1337.515741   0.930514  1566.249208  1090.744751
# 20 2019-10-23  1353.085383  15.569642  1606.935025  1079.357492
# 21 2019-10-24  1373.689860  20.604477  1638.135275  1119.829043
# 22 2019-10-25  1389.067993  15.378133  1635.052117  1151.343992
# 24 2019-10-27  1399.483396  10.415403  1647.306497  1156.680782
# 25 2019-10-28  1408.887443   9.404047  1666.007533  1153.667159
# 26 2019-10-29  1427.866737  18.979294  1684.493172  1170.696604
# 27 2019-10-30  1451.125606  23.258869  1710.437426  1217.606722
# 28 2019-10-31  1468.347585  17.221980  1714.789521  1226.445175
# 29 2019-11-01  1473.084854   4.737269  1737.111919  1229.387009
#
# Predicted Decrease:
#
#          Date     estimate     change        upper        lower
# 1  2019-10-04  1472.000543  -9.563517  1727.711946  1215.841131
# 5  2019-10-08  1485.127517  -7.707686  1732.334010  1250.940725
# 6  2019-10-09  1462.374166 -22.753351  1714.124926  1218.075920
# 7  2019-10-10  1433.182158 -29.192008  1695.572427  1178.154326
# 8  2019-10-11  1409.238580 -23.943578  1660.611699  1145.896564
# 10 2019-10-13  1400.380468  -8.858111  1637.238040  1164.631884
# 14 2019-10-17  1421.956929  -5.233528  1670.432538  1171.813270
# 15 2019-10-18  1404.624153 -17.332776  1650.543339  1148.876648
# 17 2019-10-20  1352.423961 -52.200192  1600.674833  1096.497344
# 18 2019-10-21  1336.585226 -15.838735  1596.588263  1081.558268
