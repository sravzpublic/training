# %%
import sys, os
import numpy as np
import matplotlib.pyplot as plt
sys.path.append(f"{os.getcwd()}/src")
from src import asset
from src import stocker

ae = asset.engine()
price_df = ae.get_historical_price('fut_gold')[['AdjustedClose']]
price_df.head()
price_df.dtypes
# Out:
# AdjustedClose    float64
# dtype: object

# %%
stocker.create_stocker_tear_sheet('fut_gold', stocker.CHART_TYPE_CREATE_PROPHET_MODEL, returns_df = price_df, number_of_years_back = 10)
# Out:
# /home/ubuntu/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# fut_gold Stocker Initialized. Data covers 2011-08-02 00:00:00 to 2021-07-23 00:00:00.
# Initial log joint probability = -3.50052
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       2692.15   0.000517379       261.871      0.9541      0.9541      128
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       2707.31    0.00606078       252.721       4.393      0.4393      248
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# ...

# %%
stocker.create_stocker_tear_sheet('fut_gold', stocker.CHART_TYPE_EVALUATE_PREDICTION, returns_df = price_df, number_of_years_back = 10)
# Out:
# /home/ubuntu/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# fut_gold Stocker Initialized. Data covers 2011-08-02 00:00:00 to 2021-07-23 00:00:00.
# Initial log joint probability = -6.43646
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       2760.51    0.00557649       941.201           1           1      127
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       2869.51   0.000612475       641.146      0.5483      0.5483      239
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# ...

# %%
stocker.create_stocker_tear_sheet('fut_gold', stocker.CHART_TYPE_CHANGE_POINT_PRIOR_ANALYSIS, returns_df = price_df, number_of_years_back = 10)
# Out:
# /home/ubuntu/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# fut_gold Stocker Initialized. Data covers 2011-08-02 00:00:00 to 2021-07-23 00:00:00.
# Initial log joint probability = -3.50052
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       79       2117.46    0.00054251       4105.31   1.197e-07       0.001      145  LS failed, Hessian reset
#       99       2118.68   7.12233e-07       3753.69      0.2973      0.2973      171
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# ...

# %%
stocker.create_stocker_tear_sheet('fut_gold', stocker.CHART_TYPE_CHANGE_POINT_PRIOR_VALIDATION, returns_df = price_df, number_of_years_back = 10)
# Out:
# /home/ubuntu/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# fut_gold Stocker Initialized. Data covers 2011-08-02 00:00:00 to 2021-07-23 00:00:00.
#
# Validation Range 2019-07-23 00:00:00 to 2020-07-23 00:00:00.
#
# Initial log joint probability = -4.3281
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       61       2173.57   0.000540916       4477.31   1.072e-07       0.001      132  LS failed, Hessian reset
#       99       2177.68   1.58118e-06       3966.58      0.4483      0.4483      177
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# ...

# %%
stocker.create_stocker_tear_sheet('fut_gold', stocker.CHART_TYPE_EVALUATE_PREDICTION_WITH_CHANGE_POINT, returns_df = price_df, number_of_years_back = 10)
# Out:
# /home/ubuntu/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# fut_gold Stocker Initialized. Data covers 2011-08-02 00:00:00 to 2021-07-23 00:00:00.
# Initial log joint probability = -6.43646
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       2835.41     0.0062938       4019.02           1           1      119
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199        3009.2    0.00575048       488.041           1           1      229
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# ...

# %%
stocker.create_stocker_tear_sheet('fut_gold', stocker.CHART_TYPE_PREDICT_FUTURE, returns_df = price_df, number_of_years_back = 10)
# Out:
# /home/ubuntu/.pyenv/versions/3.7.8/lib/python3.7/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# fut_gold Stocker Initialized. Data covers 2011-08-02 00:00:00 to 2021-07-23 00:00:00.
# Initial log joint probability = -3.50052
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       2692.15   0.000517379       261.871      0.9541      0.9541      128
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       2707.31    0.00606078       252.721       4.393      0.4393      248
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
# ...
